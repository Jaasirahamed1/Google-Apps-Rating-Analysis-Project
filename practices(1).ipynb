# %%
name = input("enter the name:")
age = int(input("enter the age:"))
address = input("enter the address:")
print("my name is:",name)
print("my age is:",age)
print("my address is:",address)
# Out:
# enter the name: fr
# enter the age: 3
# enter the address: ff
# my name is: fr
# my age is: 3
# my address is: ff

# %%
a = int(input())
b = int(input())
c = int(input())
d = a*b*c
e = a+b+c
f = d/e
print(f)
# Out:
#  2
#  3
#  4
# 0.375

# %%
name = input()
score = int(input())
department = input()
print(name)
print(score/10,"/10")
print(department)
# Out:
#  jaa
#  78
#  gg
# jaa
# 7.8 /10
# gg

# %%
rcb = input("Enter rcb win or not")
if (rcb == "win"):
    print("ee sala  cup namde")
else:
    print("ee salea cup nagi")
# Out:
# Enter rcb win or not win
# easale cup namatu

# %%
meghna = input("meghna died or not")
if (meghna == "died"):
    print("suriya meets priya")
else:
    print("surya weds meghna")
# Out:
# meghna died or not died
# suriya meets priya
